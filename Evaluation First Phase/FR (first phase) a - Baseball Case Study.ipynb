# %% [markdown]
# # BASEBALL CASE STUDY

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Dimension of the Data...

df.shape
# Out:
# (30, 17)

# %% [markdown]
# It shows rows of Data is 30 and column of data is 17

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# About columns ..............
#
# Problem statement :
#
#     A sports case study data from 2014 to develop the algorithm that predict the number of wins for a given team 2015 season
#     based on several different indicators of success.
#
# About Data :
#
# W ------ number of Wins
#
# R ------  Runs
#
# AB------ At Bats
#
# H -----  Hits
#
# 2B ---- Doubles
#
# 3B ----- Triples
#
# HR ----- Home runs
#
# BB ----- Walks
#
# SO ---- Strike out
#
# SB ---- Stolen Bases
#
# RA ---- Runs Allowed
#
# ER ---- Earned Runs
#
# ERA ---- Earned Runs Average
#
# CG ----- Complete Game
#
# SHO ----  Shutouts
#
# SV --- Saves
#
# E ----- Errors

# %%
df.head(5)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail(5)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# Checking the null value of the dataset..

df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# In this dataset there is no null value

# %%
# The null value shows the heatmap...

sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %%
# Complete information of dataset...

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# There is no need to change the datatype they are appropriate so we can skip the step of data conversion . Now directly jump to
#  Visualization part

# %% [markdown]
# EDA - Expolatory Data Analysis ( Data Analysis Visualization)

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20,7))
sns.heatmap(df.describe(), annot=True, linewidths = 0.1, linecolor = 'black', fmt = '0.2f')
# Out:
# <AxesSubplot:>

# %%
# Correlation of the columns with the target columns:

Find out the relationship between the variables.
# Out:
#   File "C:\Users\kumar\AppData\Local\Temp\ipykernel_10660\3555342052.py", line 3
#     Find out the relationship between the variables.
#          ^
# SyntaxError: invalid syntax

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize = (20,7))
sns.heatmap(df.corr(), annot = True, linewidth = 0.1, linecolor = 'black', fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# Checking the columns which are positively and negative correlated with the target columns :

plt.figure(figsize = (20,7))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind = 'bar', color = 'g')
plt.xlabel('Feature', fontsize = 10)
plt.ylabel('column with target names', fontsize = 10)
plt.title('correlation', fontsize= 10)
plt.show()

# %%
# Checking the Skewness :

The data shifted towards any side

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df.skew().sort_values(ascending = False)
# Out:
# R      1.200786
# E      0.890132
# CG     0.736845
# H      0.670254
# SV     0.657524
# SHO    0.565790
# HR     0.516441
# SB     0.479893
# AB     0.183437
# BB     0.158498
# 3B     0.129502
# ER     0.058710
# ERA    0.053331
# W      0.047089
# RA     0.045734
# SO    -0.156065
# 2B    -0.230650
# dtype: float64

# %% [markdown]
# We can see the skewnes of R = Runs columns , E = Errors columns, CG = Complete Game columns, H = Hits columns, SV = stolen Bases
# and we remove the skewness using the Power Transformer method

# %%
# using the PowerTransformer method for seting the skewness data:

from sklearn.preprocessing import power_transform , PowerTransformer

# %%
pt = PowerTransformer()
df_new_pt = pt.fit_transform(df)
df_new_pt
# Out:
# array([[ 1.34694657,  0.        ,  0.        ,  0.        ,  1.47768528,
#          1.03310301, -0.76462586, -1.61091476, -2.56989562,  0.93970819,
#         -0.66033096, -0.49742469, -0.50089346, -0.35984364, -0.78957937,
#          1.546378  , -0.3349525 ],
#        [ 0.21865782,  0.        ,  0.        ,  0.        ,  0.08426878,
#          1.2033202 , -0.15858141, -0.50274883,  0.13491294, -0.53969308,
#          0.17546536,  0.25797351,  0.26180619, -0.35984364,  0.25177537,
#          0.36044386, -0.53221128],
#        [ 0.02527078,  0.        ,  0.        ,  0.        ,  1.67078208,
#         -0.16026987, -0.68967629,  1.1282937 , -0.90125379,  0.2119555 ,
#         -0.67462053, -0.74690639, -0.63645949,  1.99351257, -0.24539345,
#         -0.6075936 , -1.34233137],
#        [-0.46557388,  0.        ,  0.        ,  0.        , -0.84859969,
#         -0.36052064, -0.8790486 , -1.18120722, -0.1896282 , -0.64256433,
# ...

# %%
# numpy array :
df_new = power_transform(df)
df_new
# Out:
# array([[ 1.34694657,  0.        ,  0.        ,  0.        ,  1.47768528,
#          1.03310301, -0.76462586, -1.61091476, -2.56989562,  0.93970819,
#         -0.66033096, -0.49742469, -0.50089346, -0.35984364, -0.78957937,
#          1.546378  , -0.3349525 ],
#        [ 0.21865782,  0.        ,  0.        ,  0.        ,  0.08426878,
#          1.2033202 , -0.15858141, -0.50274883,  0.13491294, -0.53969308,
#          0.17546536,  0.25797351,  0.26180619, -0.35984364,  0.25177537,
#          0.36044386, -0.53221128],
#        [ 0.02527078,  0.        ,  0.        ,  0.        ,  1.67078208,
#         -0.16026987, -0.68967629,  1.1282937 , -0.90125379,  0.2119555 ,
#         -0.67462053, -0.74690639, -0.63645949,  1.99351257, -0.24539345,
#         -0.6075936 , -1.34233137],
#        [-0.46557388,  0.        ,  0.        ,  0.        , -0.84859969,
#         -0.36052064, -0.8790486 , -1.18120722, -0.1896282 , -0.64256433,
# ...

# %%
# Checking Skewness..

pd.DataFrame(df_new, columns = df.columns).skew().sort_values(ascending = False)
# Out:
# E      0.063909
# SO     0.041170
# SHO    0.006560
# ERA    0.001746
# SV     0.000836
# AB     0.000000
# H      0.000000
# R      0.000000
# HR    -0.000065
# ER    -0.001940
# BB    -0.007760
# RA    -0.008082
# SB    -0.010455
# W     -0.027204
# 2B    -0.035315
# CG    -0.059785
# 3B    -0.072933
# dtype: float64

# %%
# Checking Outlier :

collist = df.columns.values
ncol=30
nrows=17
plt.figure(figsize=(ncol,3*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green', orient='v')
    plt.tight_layout()

# %%
# Removing the outlier using the zscore method :

from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
threshold = 3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new_z = df[(z<3).all(axis=1)]
df_new_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_new_z.shape
# Out:
# (29, 17)

# %%
df.shape
# Out:
# (30, 17)

# %%
# Percentage loss of Data :

Data_loss = ((30-29)/30)*100
Data_loss
# Out:
# 3.3333333333333335

# %%
# Seprating the columns into features and Target :

features = df.drop('W', axis = 1)
target = df['W']

# %% [markdown]
# my target variable containg int values, this is regression algorithms.

# %%
# Scalling the data using Min- Max Scaler:

from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,30):
    features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.2, random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print(f'At random state {i}, the training accuracy is :- {r2_score(target_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is :- {r2_score(target_test,pred_test)}')
    print("\n")
# Out:
# At random state 0, the training accuracy is :- 0.9609590618835543
# At random state 0, the testing accuracy is :- 0.6629341689506705
#
#
# At random state 1, the training accuracy is :- 0.9715846357165405
# At random state 1, the testing accuracy is :- 0.3841724690075786
#
#
# At random state 2, the training accuracy is :- 0.9898192153844548
# At random state 2, the testing accuracy is :- -2.081998955010787
#
#
# At random state 3, the training accuracy is :- 0.9722553885185528
# At random state 3, the testing accuracy is :- 0.4618378970602377
#
#
# At random state 4, the training accuracy is :- 0.964746149799658
# At random state 4, the testing accuracy is :- 0.4660685292728437
#
#
# At random state 5, the training accuracy is :- 0.9503092887369992
# At random state 5, the testing accuracy is :- 0.7517105066858546
#
#
# At random state 6, the training accuracy is :- 0.948947004521447
# At random state 6, the testing accuracy is :- 0.8376419521868339
#
#
# ...

# %%
# divide the data :

features_train,features_test, target_train, target_test = train_test_split(features,target,test_size=0.2,random_state = 12)

# %%
# tarin the model :

lr.fit(features_train, target_train)
pred_test = lr.predict(features_test)
print(r2_score(target_test, pred_test))
# Out:
# -1.1916550064202482

# %%
# Cross_ Validation Score : 

 to validate the performance of the model.

# %%
Train_accuracy = r2_score(target_train, pred_train)
Test_accuracy = r2_score(target_test, pred_test)

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score = cross_val_score(lr, features, target, cv=j)
    cv_mean = cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for testing is {Test_accuracy}')
    print("\n")
# Out:
# At cross fold 2 the cv score is -1.057932205834568 and accuracy score for training is -0.5898154321709221 and accuracy for testing is -1.1916550064202482
#
#
# At cross fold 3 the cv score is 0.2258846016774 and accuracy score for training is -0.5898154321709221 and accuracy for testing is -1.1916550064202482
#
#
# At cross fold 4 the cv score is 0.24952166654368527 and accuracy score for training is -0.5898154321709221 and accuracy for testing is -1.1916550064202482
#
#
# At cross fold 5 the cv score is 0.04075540667465847 and accuracy score for training is -0.5898154321709221 and accuracy for testing is -1.1916550064202482
#
#
# At cross fold 6 the cv score is 0.2515353093720216 and accuracy score for training is -0.5898154321709221 and accuracy for testing is -1.1916550064202482
#
#
# At cross fold 7 the cv score is 0.3890804644289939 and accuracy score for training is -0.5898154321709221 and accuracy for testing is -1.1916550064202482
#
#
# ...

# %%
# Here we have handled the problem of the overfitting and underfitting by checking the training and testing score :

import matplotlib.pyplot as plt
plt.figure(figsize = (6,4))
plt.scatter(x = target_test, y = pred_test, color = 'g')
plt.plot(target_test, target_test, color = 'b')
plt.xlabel('Orignal wins', fontsize = 10)
plt.ylabel('Predicted wins', fontsize = 10)
plt.title('Baseball Linear Regression', fontsize = 15)
plt.savefig('Baseball lr.png')
plt.show()

# %% [markdown]
# Regulariztion :

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso

parameter = {'alpha' : [.0001, .001, .01, .1, 1, .10],
             'random_state' : list(range(0,10))}

ls = Lasso()
clf = GridSearchCV(ls, parameter)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
# final model training :

ls = Lasso(alpha = 1, random_state=0)
ls.fit(features_train, target_train)
ls_score_training = ls.score(features_train, target_train)

# %%
pred_ls = ls.predict(features_test)
ls_score_training*100
# Out:
# 96.0431910828172

# %%
pred_ls = ls.predict(features_test)
ls = r2_score(target_test, pred_ls)
ls*100
# Out:
# -46.735867907314784

# %%
cv_score = cross_val_score(lr, features, target, cv=5)
cv_mean = cv_score.mean()
cv_mean*100
# Out:
# 4.075540667465847

# %% [markdown]
# Ensemble Technique :

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'],
              'max_features':['auto','sqrt','log2']}

rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf = RandomForestRegressor(criterion = 'mse', max_features = 'sqrt')
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test, pred_decision)
print('R2_Score :', rfs*100)

rfscore = cross_val_score(rf, features, target, cv=5)
rfc = rfscore.mean()
print('Cross val Score :', rfc*100)
# Out:
# R2_Score : 9.804818401937055
# Cross val Score : -31.765473724334015

# %%
import pickle
filename = 'Baseball_case_study.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# Conclusion :

# %%
loaded_model = pickle.load(open('Baseball_case_study.pkl', 'rb'))
result = loaded_model.score(features_test, target_test)
print(result*100)
# Out:
# 9.804818401937055

# %%
conclusion = pd.DataFrame([loaded_model.predict(features_test)[:], pred_decision[:]], index = ['Predict', 'Orignal'])

# %%
conclusion
# Out:
#              0      1      2      3      4      5
# Predict  80.65  79.03  76.34  77.96  79.98  85.42
# Orignal  80.65  79.03  76.34  77.96  79.98  85.42
